# %% [markdown]
# <a href="https://colab.research.google.com/github/fazal2545/Internship-Scam-Detection/blob/Fesal/InternGuard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -q Internship-Scam-Detection.zip
# %cd Internship-Scam-Detection
# Out:
# /content/Internship-Scam-Detection

# %%
# CELL 2 — Install requirements + NLTK data
# !pip install -q -r requirements.txt kagglehub
import nltk
for pkg in ['stopwords', 'punkt', 'punkt_tab', 'wordnet', 'omw-1.4']:
    nltk.download(pkg, quiet=True)
print('Dependencies ready.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 69.1 MB/s eta 0:00:00
# Dependencies ready.

# %%
# CELL 3 — Download / verify the dataset (fixes the 'fraudulent' KeyError)
# %cd /content/Internship-Scam-Detection
# !python src/setup_dataset.py
# Out:
# /content/Internship-Scam-Detection
# ...
# 100% 16.1M/16.1M [00:00<00:00, 40.0MB/s]
# Extracting files...
# Done. /content/Internship-Scam-Detection/dataset/fake_job_postings.csv
#   shape=(17880, 18)  (expected (17880, 18))
#   label counts={0: 17014, 1: 866}

# %%
# EDA (class distribution, word clouds)
# !python member1_ashrif/eda.py

# ML models
# !python member1_ashrif/train_logistic_regression.py
# Out:
# Word clouds saved.
# EDA outputs saved to /content/Internship-Scam-Detection/member1_ashrif/../reports
#             n_words
#               count        mean         std  min    25%    50%     75%     max
# fraudulent
# 0           17014.0  236.557952  125.969394  6.0  143.0  225.0  309.00  1359.0
# 1             866.0  184.474596  133.238384  2.0   87.0  152.5  250.75   875.0
# Loading + cleaning dataset ...
# Records: 17,880 | Fraud rate: 4.84%
# Fitting TF-IDF ...
# Applying SMOTE ...
# Training Logistic Regression ...
#
# ================ Logistic Regression ================
#               precision    recall  f1-score   support
#
#   Legitimate       0.99      0.99      0.99      3403
#         Scam       0.85      0.86      0.85       173
#
#     accuracy                           0.99      3576
#    macro avg       0.92      0.92      0.92      3576
# weighted avg       0.99      0.99      0.99      3576
#
# Confusion matrix [[TN FP] [FN TP]]:
# [[3376   27]
#  [  25  148]]
# ...

# %%
# DL models (GPU recommended for LSTM/GRU, strongly recommended for DistilBERT)
# !python member1_ashrif/train_lstm.py
# Out:
# 2026-08-15 13:48:31.846511: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-08-15 13:48:33.049642: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training Word2Vec on training corpus ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-08-15 13:50:21.422788: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ...

# %%
# !python member2_nusaik/train_random_forest.py
# Out:
# Training Random Forest ...
#
# ================ Random Forest ================
#               precision    recall  f1-score   support
#
#   Legitimate       0.98      1.00      0.99      3403
#         Scam       0.99      0.62      0.76       173
#
#     accuracy                           0.98      3576
#    macro avg       0.99      0.81      0.88      3576
# weighted avg       0.98      0.98      0.98      3576
#
# Confusion matrix [[TN FP] [FN TP]]:
# [[3402    1]
#  [  66  107]]
# ROC-AUC: 0.9874
# Saved metrics -> /content/Internship-Scam-Detection/member2_nusaik/../src/../reports/random_forest_metrics.json
# Saved confusion-matrix plot -> /content/Internship-Scam-Detection/member2_nusaik/../src/../reports/random_forest_cm.png
# Saved -> reports/rf_top_features.txt
# Saved -> models/random_forest.joblib

# %%
# !python member2_nusaik/train_gru.py
# Out:
# 2026-08-15 14:14:59.857107: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-08-15 14:14:59.956729: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-08-15 14:15:54.762566: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ...

# %%
# !python member3_fesal/train_xgboost.py
# Out:
# scale_pos_weight = 19.64
# Training XGBoost ...
# [0]	validation_0-aucpr:0.35271
# [100]	validation_0-aucpr:0.86108
# [200]	validation_0-aucpr:0.88167
# [300]	validation_0-aucpr:0.89792
# [400]	validation_0-aucpr:0.90412
# [500]	validation_0-aucpr:0.90641
# [599]	validation_0-aucpr:0.90976
#
# ================ XGBoost ================
#               precision    recall  f1-score   support
#
#   Legitimate       0.99      1.00      0.99      3403
#         Scam       0.96      0.75      0.84       173
#
#     accuracy                           0.99      3576
#    macro avg       0.97      0.87      0.92      3576
# weighted avg       0.99      0.99      0.99      3576
#
# Confusion matrix [[TN FP] [FN TP]]:
# [[3397    6]
#  [  44  129]]
# ROC-AUC: 0.9859
# Saved metrics -> /content/Internship-Scam-Detection/member3_fesal/../src/../reports/xgboost_metrics.json
# Saved confusion-matrix plot -> /content/Internship-Scam-Detection/member3_fesal/../src/../reports/xgboost_cm.png
# ...

# %%
# !python member3_fesal/train_bilstm.py
# Out:
# No GPU detected - using lighter CPU settings.
# For the full configuration: Runtime > Change runtime type > T4 GPU.
# Device: cpu | epochs=5 batch=128 max_len=150 layers=1 hidden=96
# train=12873  val=1431  test=3576  | scam rate=4.84%
# Vocabulary size: 30002
# Trainable parameters: 4,051,011
# Loss class weights: legitimate=0.525  scam=10.315
# epoch 1/5  train_loss=0.6884  val_loss=0.6463  val_f1=0.1311  (375s)
#    ^ best so far, checkpointed
# epoch 2/5  train_loss=0.4449  val_loss=0.2830  val_f1=0.5938  (377s)
#    ^ best so far, checkpointed
# epoch 3/5  train_loss=0.2456  val_loss=0.1701  val_f1=0.5098  (374s)
#    ^ best so far, checkpointed
# epoch 4/5  train_loss=0.1736  val_loss=0.2002  val_f1=0.5674  (378s)
# epoch 5/5  train_loss=0.1294  val_loss=0.1845  val_f1=0.6526  (383s)
# Early stopping.
#
# Best validation threshold: 0.958 (validation F1=0.7324)
#
# ================ BiLSTM ================
#               precision    recall  f1-score   support
#
# ...

# %%
# !python compare_models.py
# Out:
# === Model Comparison (sorted by fraud F1) ===
#               Model  Accuracy  Precision (fraud)  Recall (fraud)  F1 (fraud)  ROC-AUC
# Logistic Regression    0.9855             0.8457          0.8555      0.8506   0.9886
#             XGBoost    0.9860             0.9556          0.7457      0.8377   0.9859
#                 GRU    0.9832             0.8192          0.8382      0.8286   0.9902
#       Random Forest    0.9813             0.9907          0.6185      0.7616   0.9874
#                LSTM    0.9421             0.4525          0.9364      0.6102   0.9837
#              BiLSTM    0.9181             0.3667          0.9538      0.5297   0.9841
#
# Saved -> reports/model_comparison.csv and .md
#
# Best model by fraud-class F1: Logistic Regression (F1=0.8506, Recall=0.8555)
# Saved -> reports/model_comparison.png

# %%
# %cd /content/Internship-Scam-Detection
# !ls
# Out:
# /content/Internship-Scam-Detection
# application	   member1_ashrif  models     requirements.txt
# compare_models.py  member2_nusaik  README.md  RUN_IN_COLAB.ipynb
# dataset		   member3_fesal   reports    src

# %%
# !python application/app.py
# Out:
# Fraud-class F1 read from reports/: {'Logistic Regression': 0.8506, 'XGBoost': 0.8377, 'GRU': 0.8286, 'Random Forest': 0.7616, 'LSTM': 0.6102, 'BiLSTM': 0.5297}
# Selected ML model: Logistic Regression (F1=0.8506)
# 2026-08-15 16:51:54.116948: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-08-15 16:51:54.271743: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-08-15 16:51:59.334918: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Selected DL model: GRU (F1=0.8286)
# Serving predictions with: Logistic Regression (ML) + GRU (DL) - averaged
# ...

# %%
# !pip install pypdf python-docx

# %%
# !apt-get install -y -q tesseract-ocr
# !pip install pytesseract pillow
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# ...

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
# !apt-get install -y -q tesseract-ocr
# !pip install -q pytesseract pillow
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
import threading, time
from google.colab import output

def run_app():
    # !python application/app.py

threading.Thread(target=run_app, daemon=True).start()
time.sleep(8)
output.serve_kernel_port_as_window(5000)
# Out:
# Fraud-class F1 read from reports/: {'Logistic Regression': 0.8506, 'XGBoost': 0.8377, 'GRU': 0.8286, 'Random Forest': 0.7616, 'LSTM': 0.6102, 'BiLSTM': 0.5297}
# Selected ML model: Logistic Regression (F1=0.8506)
# 2026-08-15 16:52:56.259784: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-08-15 16:52:56.394908: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# Try `serve_kernel_port_as_iframe` instead.
