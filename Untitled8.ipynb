# %% [markdown]
# <a href="https://colab.research.google.com/github/fazal2545/Internship-Scam-Detection/blob/Ashrif/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -q Internship-Scam-Detection.zip
# %cd Internship-Scam-Detection
# Out:
# unzip:  cannot find or open Internship-Scam-Detection.zip, Internship-Scam-Detection.zip.zip or Internship-Scam-Detection.zip.ZIP.
# [Errno 2] No such file or directory: 'Internship-Scam-Detection'
# /content/Internship-Scam-Detection

# %%
# CELL 2 — Install requirements + NLTK data
# !pip install -q -r requirements.txt kagglehub
import nltk
for pkg in ['stopwords', 'punkt', 'punkt_tab', 'wordnet', 'omw-1.4']:
    nltk.download(pkg, quiet=True)
print('Dependencies ready.')
# Out:
# Dependencies ready.

# %%
# CELL 3 — Download / verify the dataset (fixes the 'fraudulent' KeyError)
# %cd /content/Internship-Scam-Detection
# !python src/setup_dataset.py
# Out:
# /content/Internship-Scam-Detection
# Downloading 'Real or Fake Job Posting Prediction' from Kaggle...
# Done. /content/Internship-Scam-Detection/dataset/fake_job_postings.csv
#   shape=(17880, 18)  (expected (17880, 18))
#   label counts={0: 17014, 1: 866}

# %%
# EDA (class distribution, word clouds)
# !python member1_ashrif/eda.py

# ML models
# !python member1_ashrif/train_logistic_regression.py
# Out:
# Word clouds saved.
# EDA outputs saved to /content/Internship-Scam-Detection/member1_ashrif/../reports
#             n_words
#               count        mean         std  min    25%    50%     75%     max
# fraudulent
# 0           17014.0  236.557952  125.969394  6.0  143.0  225.0  309.00  1359.0
# 1             866.0  184.474596  133.238384  2.0   87.0  152.5  250.75   875.0
# Loading + cleaning dataset ...
# Records: 17,880 | Fraud rate: 4.84%
# Fitting TF-IDF ...
# Applying SMOTE ...
# Training Logistic Regression ...
#
# ================ Logistic Regression ================
#               precision    recall  f1-score   support
#
#   Legitimate       0.99      0.99      0.99      3403
#         Scam       0.85      0.86      0.85       173
#
#     accuracy                           0.99      3576
#    macro avg       0.92      0.92      0.92      3576
# weighted avg       0.99      0.99      0.99      3576
#
# Confusion matrix [[TN FP] [FN TP]]:
# [[3376   27]
#  [  25  148]]
# ROC-AUC: 0.9886
# Saved metrics -> /content/Internship-Scam-Detection/member1_ashrif/../src/../reports/logistic_regression_metrics.json
# Saved confusion-matrix plot -> /content/Internship-Scam-Detection/member1_ashrif/../src/../reports/logistic_regression_cm.png
# Saved -> models/logistic_regression.joblib

# %%
# DL models (GPU recommended for LSTM/GRU, strongly recommended for DistilBERT)
# !python member1_ashrif/train_lstm.py
# Out:
# 2026-08-17 12:44:57.986066: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-08-17 12:44:58.498286: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training Word2Vec on training corpus ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-08-17 12:46:06.095481: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │     3,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,000,000 (11.44 MB)
#  Trainable params: 3,000,000 (11.44 MB)
#  Non-trainable params: 0 (0.00 B)
# Class weights: {0: np.float64(0.5254573506722504), 1: np.float64(10.32034632034632)}
# Epoch 1/8
# 101/101 - 122s - 1s/step - accuracy: 0.8286 - auc: 0.8691 - loss: 0.4749 - recall: 0.7248 - val_accuracy: 0.9119 - val_auc: 0.9493 - val_loss: 0.2265 - val_recall: 0.8596
# Epoch 2/8
# 101/101 - 116s - 1s/step - accuracy: 0.9226 - auc: 0.9686 - loss: 0.2208 - recall: 0.9324 - val_accuracy: 0.9071 - val_auc: 0.9742 - val_loss: 0.2339 - val_recall: 0.9123
# Epoch 3/8
# 101/101 - 142s - 1s/step - accuracy: 0.9525 - auc: 0.9886 - loss: 0.1264 - recall: 0.9623 - val_accuracy: 0.9441 - val_auc: 0.9796 - val_loss: 0.1515 - val_recall: 0.9123
# Epoch 4/8
# 101/101 - 142s - 1s/step - accuracy: 0.9717 - auc: 0.9957 - loss: 0.0735 - recall: 0.9780 - val_accuracy: 0.8791 - val_auc: 0.9715 - val_loss: 0.3440 - val_recall: 0.9474
# Epoch 5/8
# 101/101 - 141s - 1s/step - accuracy: 0.9769 - auc: 0.9965 - loss: 0.0593 - recall: 0.9843 - val_accuracy: 0.9762 - val_auc: 0.9656 - val_loss: 0.0918 - val_recall: 0.8947
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 530ms/step
#
# ================ LSTM ================
#               precision    recall  f1-score   support
#
#   Legitimate       1.00      0.95      0.97      3403
#         Scam       0.48      0.94      0.64       173
#
#     accuracy                           0.95      3576
#    macro avg       0.74      0.94      0.81      3576
# weighted avg       0.97      0.95      0.96      3576
#
# Confusion matrix [[TN FP] [FN TP]]:
# [[3230  173]
#  [  11  162]]
# ROC-AUC: 0.9865
# Saved metrics -> /content/Internship-Scam-Detection/member1_ashrif/../src/../reports/lstm_metrics.json
# Saved confusion-matrix plot -> /content/Internship-Scam-Detection/member1_ashrif/../src/../reports/lstm_cm.png
# Saved -> models/lstm_model.keras + models/lstm_tokenizer.joblib
